# %%
import requests
import pandas as pd
import numpy as np
import rich

# %%
ROS_LATITUDE = -32.95
ROS_LONGITUDE = -60.64
https://api.open-meteo.com/v1/forecast?latitude=-32.95&longitude=-60.64&daily=weathercode,,,&=true&timezone=America%2FSao_Paulo&forecast_days=1
apparent_temperature_min
,apparent_temperature_max
,precipitation_sum
precipitation_hours


current_weather: True
query_params = {
  'latitude': ROS_LATITUDE,
  'longitude': ROS_LONGITUDE,
  'forecast_days': 1,
  'daily': ['weathercode', 'temperature', 'temperature_2m_max', 'temperature_2m_max', 'temperature_2m_min', 'apparent_temperature_max', 'apparent_temperature_mim', precipitation_probability_max],
  'timezone': 'America/Sao_Paulo'
}
# Out:
# dict_keys(['latitude', 'longitude', 'generationtime_ms', 'utc_offset_seconds', 'timezone', 'timezone_abbreviation', 'elevation'])

# %%
res
# Out:
# {'latitude': -33.0,
#  'longitude': -60.625,
#  'generationtime_ms': 0.08106231689453125,
#  'utc_offset_seconds': 0,
#  'timezone': 'GMT',
#  'timezone_abbreviation': 'GMT',
#  'elevation': 32.0}

# %% [markdown]
# # WMO Interpretation Codes
# - 0	Clear sky
# - 1, 2, 3	Mainly clear, partly cloudy, and overcast
# - 45, 48	Fog and depositing rime fog
# - 51, 53, 55	Drizzle: Light, moderate, and dense intensity
# - 56, 57	Freezing Drizzle: Light and dense intensity
# - 61, 63, 65	Rain: Slight, moderate and heavy intensity
# - 66, 67	Freezing Rain: Light and heavy intensity
# - 71, 73, 75	Snow fall: Slight, moderate, and heavy intensity
# - 77	Snow grains
# - 80, 81, 82	Rain showers: Slight, moderate, and violent
# - 85, 86	Snow showers slight and heavy
# - 95 *	Thunderstorm: Slight or moderate
# - 96, 99 *	Thunderstorm with slight and heavy hail

# %% [markdown]
# <!-- # WMO Interpretation Codes
# # 0	Clear sky
# # 1, 2, 3	Mainly clear, partly cloudy, and overcast
# # 45, 48	Fog and depositing rime fog
# # 51, 53, 55	Drizzle: Light, moderate, and dense intensity
# # 56, 57	Freezing Drizzle: Light and dense intensity
# # 61, 63, 65	Rain: Slight, moderate and heavy intensity
# # 66, 67	Freezing Rain: Light and heavy intensity
# # 71, 73, 75	Snow fall: Slight, moderate, and heavy intensity
# # 77	Snow grains
# # 80, 81, 82	Rain showers: Slight, moderate, and violent
# # 85, 86	Snow showers slight and heavy
# # 95 *	Thunderstorm: Slight or moderate
# # 96, 99 *	Thunderstorm with slight and heavy hail -->

# %%
res['hourly']
# Out:
# {'time': ['2023-07-03T00:00',
#   '2023-07-03T01:00',
#   '2023-07-03T02:00',
#   '2023-07-03T03:00',
#   '2023-07-03T04:00',
#   '2023-07-03T05:00',
#   '2023-07-03T06:00',
#   '2023-07-03T07:00',
#   '2023-07-03T08:00',
#   '2023-07-03T09:00',
#   '2023-07-03T10:00',
#   '2023-07-03T11:00',
#   '2023-07-03T12:00',
#   '2023-07-03T13:00',
#   '2023-07-03T14:00',
#   '2023-07-03T15:00',
#   '2023-07-03T16:00',
#   '2023-07-03T17:00',
#   '2023-07-03T18:00',
#   '2023-07-03T19:00',
#   '2023-07-03T20:00',
#   '2023-07-03T21:00',
#   '2023-07-03T22:00',
#   '2023-07-03T23:00',
#   '2023-07-04T00:00',
#   '2023-07-04T01:00',
#   '2023-07-04T02:00',
#   '2023-07-04T03:00',
#   '2023-07-04T04:00',
#   '2023-07-04T05:00',
#   '2023-07-04T06:00',
#   '2023-07-04T07:00',
#   '2023-07-04T08:00',
#   '2023-07-04T09:00',
#   '2023-07-04T10:00',
#   '2023-07-04T11:00',
#   '2023-07-04T12:00',
#   '2023-07-04T13:00',
#   '2023-07-04T14:00',
#   '2023-07-04T15:00',
#   '2023-07-04T16:00',
# ...
